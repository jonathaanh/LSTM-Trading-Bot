# %%
from binance.spot import Spot 
import pandas as pd
import plotly.graph_objects as go
from IPython.display import display

base_url = "https://api.binance.com"
base_url_test = "https://testnet.binance.vision"
client = Spot(base_url=base_url)

# %%
exchange_info = client.exchange_info()
#print(exchange_info)

symbols = pd.DataFrame(exchange_info['symbols'])
#print(symbols)

btcusd = client.ticker_price('BTCUSDT')
#print(btcusd)

btcusd_history = client.klines('BTCUSDT', "5m", limit=1000)
#display(btcusd_history[:2])

columns = ['time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades'
, 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
btcusd_history_df = pd.DataFrame(btcusd_history, columns=columns)
btcusd_history_df['time'] = pd.to_datetime(btcusd_history_df['time'], unit='ms')

display(btcusd_history_df)
# Out:
#                    time            open            high             low  \
# 0   2022-08-09 10:00:00  23472.62000000  23531.87000000  23336.15000000
# 1   2022-08-09 11:00:00  23350.39000000  23414.35000000  23182.55000000
# 2   2022-08-09 12:00:00  23263.34000000  23307.30000000  23200.27000000
# 3   2022-08-09 13:00:00  23245.15000000  23327.07000000  23012.85000000
# 4   2022-08-09 14:00:00  23068.42000000  23125.15000000  22865.00000000
# ..                  ...             ...             ...             ...
# 995 2022-09-19 21:00:00  19518.93000000  19686.20000000  19477.60000000
# 996 2022-09-19 22:00:00  19516.67000000  19680.00000000  19459.54000000
# 997 2022-09-19 23:00:00  19601.35000000  19638.35000000  19513.11000000
# 998 2022-09-20 00:00:00  19537.02000000  19634.62000000  19432.66000000
# 999 2022-09-20 01:00:00  19517.82000000  19521.82000000  19442.12000000
#
#               close          volume     close_time  quote_asset_volume  \
# 0    23350.39000000  11390.69368000  1660042799999  266762676.53482650
# 1    23263.92000000  10167.91590000  1660046399999  237146575.87554870
# 2    23244.76000000   6710.68571000  1660049999999  156105263.31124290
# 3    23068.42000000  10670.07679000  1660053599999  247833131.50600240
# 4    23098.85000000  11832.48045000  1660057199999  272308089.94388070
# ..              ...             ...            ...                 ...
# 995  19518.49000000   8742.89951000  1663624799999  170974467.36949480
# 996  19603.17000000  10901.50683000  1663628399999  213073835.87740170
# 997  19537.02000000   9167.08273000  1663631999999  179343171.28471610
# 998  19516.89000000  13764.63947000  1663635599999  268812689.65909130
# 999  19453.49000000   2657.29016000  1663639199999   51754038.01916780
#
#      number_of_trades taker_buy_base_asset_volume  \
# 0              359631               5709.98404000
# 1              313980               4872.55587000
# 2              247205               3300.99030000
# 3              327054               5076.30239000
# 4              352927               5845.37169000
# ..                ...                         ...
# 995            202824               4480.83240000
# 996            208118               5480.91395000
# 997            164998               4449.48714000
# 998            263821               6886.03477000
# 999             40539               1276.77645000
#
#     taker_buy_quote_asset_volume ignore
# 0             133733481.62300130      0
# 1             113650570.79226840      0
# 2              76793710.07883880      0
# 3             117951338.15309580      0
# 4             134548601.09108610      0
# ..                           ...    ...
# 995            87631715.64344120      0
# 996           107135714.44131810      0
# 997            87052343.73141730      0
# 998           134484013.44007020      0
# 999            24866345.27876140      0
#
# [1000 rows x 12 columns]

# %%
fig = go.Figure(data=[go.Candlestick(x=btcusd_history_df['time'], open=btcusd_history_df['open'], 
high=btcusd_history_df['high'], low=btcusd_history_df['low'], close=btcusd_history_df['close'])])
fig.display()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     916             method = get_real_method(obj, self.print_method)
#     917             if method is not None:
# --> 918                 method()
#     919                 return True
#     920
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotly/basedatatypes.py in _ipython_display_(self)
#     840
#     841         if pio.renderers.render_on_display and pio.renderers.default:
# --> 842             pio.show(self)
#     843         else:
#     844             print(repr(self))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotly/io/_renderers.py in show(fig, renderer, validate, **kwargs)
#     395         if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
#     396             raise ValueError(
# --> 397                 "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398             )
#     399
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'close': array(['23350.39000000', '23263.92000000', '23244.76000000', ...,
#                               '19537.02000000', '19516.89000000', '19453.49000000'], dtype=object),
#               'high': array(['23531.87000000', '23414.35000000', '23307.30000000', ...,
#                              '19638.35000000', '19634.62000000', '19521.82000000'], dtype=object),
#               'low': array(['23336.15000000', '23182.55000000', '23200.27000000', ...,
#                             '19513.11000000', '19432.66000000', '19442.12000000'], dtype=object),
#               'open': array(['23472.62000000', '23350.39000000', '23263.34000000', ...,
#                              '19601.35000000', '19537.02000000', '19517.82000000'], dtype=object),
#               'type': 'candlestick',
#               'x': array([datetime.datetime(2022, 8, 9, 10, 0),
#                           datetime.datetime(2022, 8, 9, 11, 0),
#                           datetime.datetime(2022, 8, 9, 12, 0), ...,
#                           datetime.datetime(2022, 9, 19, 23, 0),
#                           datetime.datetime(2022, 9, 20, 0, 0),
#                           datetime.datetime(2022, 9, 20, 1, 0)], dtype=object)}],
#     'layout': {'template': '...'}
# })

# %%
btcusd_history_df.to_pickle("data.pandas")
