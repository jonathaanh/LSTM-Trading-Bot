# %%
from binance.spot import Spot 
import pandas as pd
import plotly.graph_objects as go
from IPython.display import display

base_url = "https://api.binance.com"
base_url_test = "https://testnet.binance.vision"
client = Spot(base_url=base_url)

# %%
exchange_info = client.exchange_info()
#print(exchange_info)

symbols = pd.DataFrame(exchange_info['symbols'])
#print(symbols)

btcusd = client.ticker_price('BTCUSDT')
#print(btcusd)

btcusd_history = client.klines('BTCUSDT', "1h", limit=1000)
#display(btcusd_history[:2])

columns = ['time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades'
, 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
btcusd_history_df = pd.DataFrame(btcusd_history, columns=columns)
btcusd_history_df['time'] = pd.to_datetime(btcusd_history_df['time'], unit='ms')

display(btcusd_history_df)
# Out:
#                    time            open            high             low  \
# 0   2022-08-09 09:00:00  23777.27000000  23829.00000000  23470.00000000
# 1   2022-08-09 10:00:00  23472.62000000  23531.87000000  23336.15000000
# 2   2022-08-09 11:00:00  23350.39000000  23414.35000000  23182.55000000
# 3   2022-08-09 12:00:00  23263.34000000  23307.30000000  23200.27000000
# 4   2022-08-09 13:00:00  23245.15000000  23327.07000000  23012.85000000
# ..                  ...             ...             ...             ...
# 995 2022-09-19 20:00:00  19514.80000000  19645.00000000  19413.53000000
# 996 2022-09-19 21:00:00  19518.93000000  19686.20000000  19477.60000000
# 997 2022-09-19 22:00:00  19516.67000000  19680.00000000  19459.54000000
# 998 2022-09-19 23:00:00  19601.35000000  19638.35000000  19513.11000000
# 999 2022-09-20 00:00:00  19537.02000000  19634.62000000  19432.66000000
#
#               close          volume     close_time  quote_asset_volume  \
# 0    23472.62000000  10055.90053000  1660039199999  237852766.84073580
# 1    23350.39000000  11390.69368000  1660042799999  266762676.53482650
# 2    23263.92000000  10167.91590000  1660046399999  237146575.87554870
# 3    23244.76000000   6710.68571000  1660049999999  156105263.31124290
# 4    23068.42000000  10670.07679000  1660053599999  247833131.50600240
# ..              ...             ...            ...                 ...
# 995  19518.93000000  14824.33438000  1663621199999  289214017.37825970
# 996  19518.49000000   8742.89951000  1663624799999  170974467.36949480
# 997  19603.17000000  10901.50683000  1663628399999  213073835.87740170
# 998  19537.02000000   9167.08273000  1663631999999  179343171.28471610
# 999  19513.26000000  13522.70865000  1663635599999  264091683.39393510
#
#      number_of_trades taker_buy_base_asset_volume  \
# 0              331755               4511.56982000
# 1              359631               5709.98404000
# 2              313980               4872.55587000
# 3              247205               3300.99030000
# 4              327054               5076.30239000
# ..                ...                         ...
# 995            239244               7673.82330000
# 996            202824               4480.83240000
# 997            208118               5480.91395000
# 998            164998               4449.48714000
# 999            260059               6764.02276000
#
#     taker_buy_quote_asset_volume ignore
# 0             106731650.79889560      0
# 1             133733481.62300130      0
# 2             113650570.79226840      0
# 3              76793710.07883880      0
# 4             117951338.15309580      0
# ..                           ...    ...
# 995           149725303.96174800      0
# 996            87631715.64344120      0
# 997           107135714.44131810      0
# 998            87052343.73141730      0
# 999           132103009.49878450      0
#
# [1000 rows x 12 columns]

# %%
# fig = go.Figure(data=[go.Candlestick(x=btcusd_history_df['time'], open=btcusd_history_df['open'], 
# high=btcusd_history_df['high'], low=btcusd_history_df['low'], close=btcusd_history_df['close'])])

btcusd_history_df.to_pickle("data.pandas")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/49/bcxc1r5j37q1h9tb07sj96440000gn/T/ipykernel_86656/1489364141.py in <module>
#       2 # high=btcusd_history_df['high'], low=btcusd_history_df['low'], close=btcusd_history_df['close'])])
#       3
# ----> 4 pd.to_pickle("data.pandas")
#
# TypeError: to_pickle() missing 1 required positional argument: 'filepath_or_buffer'
